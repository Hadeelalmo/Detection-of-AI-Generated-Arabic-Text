# %% [markdown]
# <a href="https://colab.research.google.com/github/Hadeelalmo/Detection-of-AI-Generated-Arabic-Text/blob/main/notebooks/p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("KFUPM-JRCAI/arabic-generated-abstracts")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/8.10k [00:00<?, ?B/s]
# data/by_polishing-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B / 8.49MB
# data/by_polishing-00000-of-00001.parquet: downloading bytes:           |  0.00B
# data/from_title-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B / 6.90MB
# data/from_title-00000-of-00001.parquet: downloading bytes:           |  0.00B
# data/from_title_and_content-00000-of-000(…): reconstructing file:   0%|          |  0.00B / 7.01MB
# data/from_title_and_content-00000-of-000(…): downloading bytes:           |  0.00B
# ...
# Generating from_title_and_content split:   0%|          | 0/2574 [00:00<?, ? examples/s]

# %%
dataset["by_polishing"].features
# Out:
# {'original_abstract': Value('string'),
#  'allam_generated_abstract': Value('string'),
#  'jais_generated_abstract': Value('string'),
#  'llama_generated_abstract': Value('string'),
#  'openai_generated_abstract': Value('string')}

# %%
dataset["from_title"].features
# Out:
# {'original_abstract': Value('string'),
#  'allam_generated_abstract': Value('string'),
#  'jais_generated_abstract': Value('string'),
#  'llama_generated_abstract': Value('string'),
#  'openai_generated_abstract': Value('string')}

# %%
datset["from_title_and_content"].features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_553/2082616814.py in <cell line: 0>()
# ----> 1 datset["from_title_and_content"].features
#
# NameError: name 'datset' is not defined

# %%
dataset = load_dataset("KFUPM-JRCAI/arabic-generated-abstracts")

# %%
dataset["from_title_and_content"].features
# Out:
# {'original_abstract': Value('string'),
#  'allam_generated_abstract': Value('string'),
#  'jais_generated_abstract': Value('string'),
#  'llama_generated_abstract': Value('string'),
#  'openai_generated_abstract': Value('string')}

# %%
data = dataset["by_polishing"].to_pandas()

# %%
Missing_values = data.isnull().sum()

# %%
print(Missing_values)
# Out:
# original_abstract            0
# allam_generated_abstract     0
# jais_generated_abstract      0
# llama_generated_abstract     0
# openai_generated_abstract    0
# dtype: int64

# %%
data = dataset["from_title"].to_pandas()

# %%
Missing_values = data.isnull().sum()
print(Missing_values)
# Out:
# original_abstract            0
# allam_generated_abstract     0
# jais_generated_abstract      0
# llama_generated_abstract     0
# openai_generated_abstract    0
# dtype: int64

# %%
data = dataset["from_title_and_content"].to_pandas()
Missing_values = data.isnull().sum()
print(Missing_values)
# Out:
# original_abstract            0
# allam_generated_abstract     0
# jais_generated_abstract      0
# llama_generated_abstract     0
# openai_generated_abstract    0
# dtype: int64

# %%
data = dataset["by_polishing"].to_pandas()
duplicates = data.duplicated().sum()
print("Number of duplicate rows:"), duplicates
# Out:
# Number of duplicate rows:
# (None, np.int64(0))

# %%
data = dataset["from_title"].to_pandas()
duplicates = data.duplicated().sum()
print("Number of duplicate rows:"), duplicates
# Out:
# Number of duplicate rows:
# (None, np.int64(0))

# %%
data = dataset["from_title_and_content"].to_pandas()
duplicates = data.duplicated().sum()
print("Number of duplicate rows:"), duplicates
# Out:
# Number of duplicate rows:
# (None, np.int64(0))

# %%
data = dataset["by_polishing"].to_pandas()

for column in data.columns:
    inconsistent = data[column].astype(str).str.strip().eq("").sum()
    print(column, ":", inconsistent)
# Out:
# original_abstract : 0
# allam_generated_abstract : 0
# jais_generated_abstract : 0
# llama_generated_abstract : 0
# openai_generated_abstract : 0

# %%
data = dataset["from_title"].to_pandas()

for column in data.columns:
    inconsistent = data[column].astype(str).str.strip().eq("").sum()
    print(column, ":", inconsistent)
# Out:
# original_abstract : 0
# allam_generated_abstract : 0
# jais_generated_abstract : 0
# llama_generated_abstract : 0
# openai_generated_abstract : 0

# %%
data = dataset["from_title_and_content"].to_pandas()

for column in data.columns:
    inconsistent = data[column].astype(str).str.strip().eq("").sum()
    print(column, ":", inconsistent)
# Out:
# original_abstract : 0
# allam_generated_abstract : 0
# jais_generated_abstract : 0
# llama_generated_abstract : 0
# openai_generated_abstract : 0
